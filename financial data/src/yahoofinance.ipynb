# %% [markdown]
# # Yahoo Finance API
#
# https://ranaroussi.github.io/yfinance/

# %% [markdown]
# ## Step 1
# Download the Python package `yfinance`

# %%
pip install yfinance
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 63.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 57.5 MB/s eta 0:00:00
# ...
#   Created wheel for multitasking: filename=multitasking-0.0.12-py3-none-any.whl size=15549 sha256=4c4ca6f4d9cb5a087a5746ba3bc4245d5bd93dd5154a0f512781cdd00d3821d3
#   Stored in directory: /Users/declanloo/Library/Caches/pip/wheels/42/d6/84/bf57a755f4569494cd00de4bb46ef064874823f4d19c82e960
# ...
#   Created wheel for peewee: filename=peewee-3.18.3-cp311-cp311-macosx_11_0_arm64.whl size=264602 sha256=4c31bef8481d01a482e2344038d3f60ac400cccae44516cc347cd12ebd14811c
#   Stored in directory: /Users/declanloo/Library/Caches/pip/wheels/05/dc/94/4ba26d23cac9aee7481d3dfcc7e99ce2cc5731230ec10f7ec1
# Successfully built multitasking peewee
# ...

# %% [markdown]
# ## Step 2
# Import to Python

# %%
import yfinance as yf

# %% [markdown]
# ## Step 3
# Get Ticker data based on Symbols

# %%
symbol = 'NVDA'

dat = yf.Ticker(symbol)

dat.info
# Out:
# {'address1': '2788 San Tomas Expressway',
#  'city': 'Santa Clara',
#  'state': 'CA',
#  'zip': '95051',
#  'country': 'United States',
#  'phone': '408 486 2000',
#  'website': 'https://www.nvidia.com',
#  'industry': 'Semiconductors',
#  'industryKey': 'semiconductors',
#  'industryDisp': 'Semiconductors',
#  'sector': 'Technology',
#  'sectorKey': 'technology',
#  'sectorDisp': 'Technology',
# ...

# %%
dat.history(period='5d')
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2025-12-16 00:00:00-05:00  176.259995  178.490005  174.899994  177.720001
# 2025-12-17 00:00:00-05:00  176.100006  176.130005  170.309998  170.940002
# 2025-12-18 00:00:00-05:00  174.529999  176.149994  171.820007  174.139999
# 2025-12-19 00:00:00-05:00  176.669998  181.449997  176.339996  180.990005
# 2025-12-22 00:00:00-05:00  183.919998  184.000000  182.789993  183.324997
#
#                               Volume  Dividends  Stock Splits
# Date
# 2025-12-16 00:00:00-05:00  148588100        0.0           0.0
# 2025-12-17 00:00:00-05:00  222775500        0.0           0.0
# 2025-12-18 00:00:00-05:00  176096000        0.0           0.0
# 2025-12-19 00:00:00-05:00  324372500        0.0           0.0
# 2025-12-22 00:00:00-05:00   40962875        0.0           0.0
